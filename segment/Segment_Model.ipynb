# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
import h5py

from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # GPU

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"
cfg = tf.compat.v1.ConfigProto() 
cfg.gpu_options.visible_device_list="0"
cfg.gpu_options.allow_growth=True
cfg.gpu_options.per_process_gpu_memory_fraction = 0.7# 使用50%的GPU暫存  
session = tf.compat.v1.Session(config=cfg )

# %%
def solve_cudnn_error():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
        except RuntimeError as e:
            # Memory growth must be set before GPUs have been initialized
            print(e)

# %%
solve_cudnn_error()
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# # Train data dliate

# %%
data_folder = 'train/image/'
mask_folder = 'train/mask/'
DILATE_KERNEL = np.ones((9, 9), np.uint8)
for filename in os.listdir(data_folder):
    img = cv2.imread(os.path.join(data_folder, filename))
    mask_img = cv2.imread(os.path.join(mask_folder, filename), cv2.IMREAD_GRAYSCALE)
    if img.shape !=(512,512,3):
        print(filename)
        img=cv2.resize(img,(512,512))
        mask_img=cv2.resize(mask_img,(512,512))
        cv2.imwrite("train\{}".format(filename),img)
        cv2.imwrite("train\mask{}".format(filename),mask_img)
    mask_dilate = cv2.dilate(mask_img, DILATE_KERNEL, iterations=1)
    cv2.imwrite("train\dilate\{}".format(filename),mask_dilate)
# Out:
# 1.jpg
# 10.jpg
# 100.jpg
# 1000.jpg
# 1001.jpg
# 1002.jpg
# 1003.jpg
# 1004.jpg
# 1005.jpg
# 1006.jpg
# 1007.jpg
# 1008.jpg
# 1009.jpg
# 101.jpg
# 1010.jpg
# 1011.jpg
# 1012.jpg
# 1013.jpg
# 1014.jpg
# 1015.jpg
# 1016.jpg
# 1017.jpg
# 1018.jpg
# 1019.jpg
# 102.jpg
# 1020.jpg
# 1021.jpg
# 1022.jpg
# 1023.jpg
# 1024.jpg
# 1025.jpg
# 1026.jpg
# 1027.jpg
# 1028.jpg
# 1029.jpg
# 103.jpg
# 1030.jpg
# 1031.jpg
# 1032.jpg
# 1033.jpg
# 1034.jpg
# 1035.jpg
# 1036.jpg
# 1037.jpg
# 1038.jpg
# 1039.jpg
# 104.jpg
# 1040.jpg
# 1041.jpg
# 1042.jpg
# 1043.jpg
# 1044.jpg
# 1045.jpg
# 1046.jpg
# 1047.jpg
# 1048.jpg
# 1049.jpg
# 105.jpg
# 1050.jpg
# 1051.jpg
# 1052.jpg
# 1053.jpg
# 1054.jpg
# 1055.jpg
# 1056.jpg
# 1057.jpg
# 1058.jpg
# 1059.jpg
# 106.jpg
# 1060.jpg
# 1061.jpg
# 1062.jpg
# 1063.jpg
# 1064.jpg
# 1065.jpg
# 1066.jpg
# 1067.jpg
# 1068.jpg
# 1069.jpg
# 107.jpg
# 1070.jpg
# 1071.jpg
# 1072.jpg
# 1073.jpg
# 1074.jpg
# 1075.jpg
# 1076.jpg
# 1077.jpg
# 1078.jpg
# 930.jpg
# 931.jpg
# 932.jpg
# 933.jpg
# 934.jpg
# 935.jpg
# 936.jpg
# 937.jpg
# 938.jpg
# 939.jpg
# 94.jpg
# 940.jpg
# 941.jpg
# 942.jpg
# 943.jpg
# 944.jpg
# 945.jpg
# 946.jpg
# 947.jpg
# 948.jpg
# 949.jpg
# 95.jpg
# 950.jpg
# 951.jpg
# 952.jpg
# 953.jpg
# 954.jpg
# 955.jpg
# 956.jpg
# 957.jpg
# 958.jpg
# 959.jpg
# 96.jpg
# 960.jpg
# 961.jpg
# 962.jpg
# 963.jpg
# 964.jpg
# 965.jpg
# 966.jpg
# 967.jpg
# 968.jpg
# 969.jpg
# 97.jpg
# 970.jpg
# 971.jpg
# 972.jpg
# 973.jpg
# 974.jpg
# 975.jpg
# 976.jpg
# 977.jpg
# 978.jpg
# 979.jpg
# 98.jpg
# 980.jpg
# 981.jpg
# 982.jpg
# 983.jpg
# 984.jpg
# 985.jpg
# 986.jpg
# 987.jpg
# 988.jpg
# 989.jpg
# 99.jpg
# 990.jpg
# 991.jpg
# 992.jpg
# 993.jpg
# 994.jpg
# 995.jpg
# 996.jpg
# 997.jpg
# 998.jpg
# 999.jpg

# %% [markdown]
# # Test data dilate

# %%
data_folder = 'test/image/'
mask_folder = 'test/mask/'
DILATE_KERNEL = np.ones((15, 15), np.uint8)
for filename in os.listdir(data_folder):
    img = cv2.imread(os.path.join(data_folder, filename))
    mask_img = cv2.imread(os.path.join(mask_folder, filename), cv2.IMREAD_GRAYSCALE)
    if img.shape !=(512,512,3):
        print(filename)
        img=cv2.resize(img,(512,512))
        mask_img=cv2.resize(mask_img,(512,512))
    mask_dilate = cv2.dilate(mask_img, DILATE_KERNEL, iterations=1)
    cv2.imwrite("test\dilate\{}".format(filename),mask_dilate)

# %% [markdown]
# ## figure

# %%
def add_colored_dilate(image, mask_image, dilate_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    dilate_image_gray = cv2.cvtColor(dilate_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    dilate = cv2.bitwise_and(dilate_image, dilate_image, mask=dilate_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])
    dilate_coord = np.where(dilate!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]
    dilate[dilate_coord[0],dilate_coord[1],:] = [0,0,255]

    ret = cv2.addWeighted(image, 0.7, dilate, 0.3, 0)
    ret = cv2.addWeighted(ret, 0.7, mask, 0.3, 0)

    return ret

# %%
def add_colored_mask(image, mask_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]

    ret = cv2.addWeighted(image, 0.7, mask, 0.3, 0)

    return ret

# %%
def diff_mask(ref_image, mask_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]

    ret = cv2.addWeighted(ref_image, 0.7, mask, 0.3, 0)
    return ret

# %%
data_folder = 'train/image/'
mask_folder = 'train/mask/'
dilate_folder="train/dilate/"
base_file = os.listdir(data_folder)

image_file = os.path.join(data_folder, base_file[10])
mask_image_file = os.path.join(mask_folder, base_file[10])
dilate_image_file = os.path.join(dilate_folder, base_file[10])

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)
                          
fig, axs = plt.subplots(2, 4, figsize=(16, 8))

axs[0, 0].set_title("CT")
axs[0, 0].imshow(image)

axs[0, 1].set_title("Mask")
axs[0, 1].imshow(mask_image)

axs[0, 2].set_title("Dilate")
axs[0, 2].imshow(dilate_image)

axs[0, 3].set_title("Merged")
axs[0, 3].imshow(merged_image)

image_file = os.path.join(data_folder, base_file[52])
mask_image_file = os.path.join(mask_folder, base_file[52])
dilate_image_file = os.path.join(dilate_folder, base_file[52])

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)
axs[1, 0].set_title("CT")
axs[1, 0].imshow(image)

axs[1, 1].set_title("Mask")
axs[1, 1].imshow(mask_image)

axs[1, 2].set_title("Dilate")
axs[1, 2].imshow(dilate_image)

axs[1, 3].set_title("Merged")
axs[1, 3].imshow(merged_image)

# %% [markdown]
# ## Data

# %%
train_data_folder = 'train/image/'
test_data_folder="test/case/image/"
train_mask_folder = 'train/mask/'
train_dilate_folder="train/dilate/"
train_files= [file for file in os.listdir(train_data_folder) if file.lower().endswith('.jpg')]
test_files=[file for file in os.listdir(test_data_folder) if file.lower().endswith('.jpg')]
mask_files=[file for file in os.listdir(train_mask_folder) if file.lower().endswith('.jpg')]
dilate_files=[file for file in os.listdir(train_dilate_folder) if file.lower().endswith('.jpg')]
(len(train_files), \
 len(test_files), \
 len(mask_files), \
 len(dilate_files))
# Out:
# (1652, 108, 1652, 1652)

# %%
def train_generator(batch_size, train_path, image_folder, mask_folder, aug_dict,
        image_color_mode="grayscale",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(512,512),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

def add_suffix(base_file, suffix):
    filename, fileext = os.path.splitext(base_file)
    return "%s_%s%s" % (filename, suffix, fileext)

# %%
def test_load_image(test_file, target_size=(512,512)):
    img = cv2.imread(test_file, cv2.IMREAD_GRAYSCALE)
    img_size=np.zeros([512,512],dtype="uint8")
    gaussian_blur = cv2.bilateralFilter(img,15,75,75)
    img_size[51:461,51:461]=gaussian_blur[51:461,51:461]
    img = img_size / 255
    img = cv2.resize(img, target_size)
    img = np.reshape(img, img.shape + (1,))
    img = np.reshape(img,(1,) + img.shape)
    return img

def test_generator(test_files,test_data_folder , target_size=(512,512)):
    for test_file in test_files:
        test_file=os.path.join(test_data_folder,test_file)
        yield test_load_image(test_file, target_size)
        
def save_result(save_path, npyfile, test_files):
    for i, item in enumerate(npyfile):
        result_file = test_files[i]
        img = (item[:, :, 0] * 255.).astype(np.uint8)

        filename, fileext = os.path.splitext(os.path.basename(result_file))

        result_file = os.path.join(save_path, "%s_predict%s" % (filename, fileext))

        cv2.imwrite(result_file, img)

# %% [markdown]
# ## Model

# %%
def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(512,512,1)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(inputs)
    conv1 = Dropout(0.1)(conv1)
    conv1 = Conv2D(32, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(pool1)
    conv2 = Dropout(0.1)(conv2)
    conv2 = Conv2D(64, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(pool2)
    conv3 = Dropout(0.2)(conv3)
    conv3 = Conv2D(128, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(pool3)
    conv4 = Dropout(0.2)(conv4)
    conv4 = Conv2D(256, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(pool4)
    conv5 = Dropout(0.3)(conv5)
    conv5 = Conv2D(512, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(up6)
    conv6 = Dropout(0.2)(conv6)
    conv6 = Conv2D(256, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(up7)
    conv7 = Dropout(0.2)(conv7)
    conv7 = Conv2D(128, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(up8)
    conv8 = Dropout(0.1)(conv8)
    conv8 = Conv2D(64, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(up9)
    conv9 = Dropout(0.1)(conv9)
    conv9 = Conv2D(32, (3, 3), activation='relu',kernel_initializer="he_normal", padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
BATCH_SIZE=2
EPOCHS=50
train_generator_args = dict(rotation_range=4.5,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=False,
                            fill_mode='nearest')

train_gen = train_generator(BATCH_SIZE,
                            "train/",
                            'image',
                            'dilate', 
                            train_generator_args,
                            target_size=(512,512))

validation_data =train_generator(BATCH_SIZE,
                            "test/",
                            'image',
                            'dilate', 
                            train_generator_args,
                            target_size=(512,512)
                           )

# %% [markdown]
# ## Train Model

# %%
model = unet(input_size=(512,512
                         
                         ,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss, \
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()

model_checkpoint = ModelCheckpoint('unet_gallbladder_seg.hdf5', 
                                   monitor='loss', 
                                   verbose=1, 
                                   save_best_only=True)

history = model.fit_generator(train_gen,
                              steps_per_epoch=len(train_files) / BATCH_SIZE, 
                              epochs=EPOCHS, 
                              callbacks=[model_checkpoint],
                              validation_data = validation_data,
                             validation_steps =200)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 512, 512, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512, 512, 32) 0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 512, 512, 32) 9248        dropout_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 256, 256, 32) 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 256, 64) 18496       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256, 256, 64) 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 256, 256, 64) 36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 73856       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 128 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 147584      dropout_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 256)  295168      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64, 64, 256)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 256)  590080      dropout_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 512)  1180160     max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 512)  0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 512)  2359808     dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 256)  524544      conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64, 64, 256)  0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 256)  590080      dropout_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 128 295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 128, 128, 128 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 128 147584      dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 256, 256, 64) 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 64) 36928       dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 512, 512, 64) 0           conv2d_transpose_5[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 512, 512, 32) 18464       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 512, 512, 32) 0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 512, 512, 32) 9248        dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 512, 512, 1)  33          conv2d_28[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# Found 40 images belonging to 1 classes.
# Found 1652 images belonging to 1 classes.
# Found 40 images belonging to 1 classes.
# Found 1652 images belonging to 1 classes.
# 826/826 [==============================] - 329s 398ms/step - loss: -0.2640 - dice_coef: 0.2640 - binary_accuracy: 0.8517 - val_loss: -0.1732 - val_dice_coef: 0.1961 - val_binary_accuracy: 0.8636
#
# Epoch 00001: loss improved from inf to -0.26404, saving model to unet_gallbladder_seg.hdf5
# Epoch 2/50
# 826/826 [==============================] - 324s 393ms/step - loss: -0.4666 - dice_coef: 0.4666 - binary_accuracy: 0.9849 - val_loss: -0.1756 - val_dice_coef: 0.2834 - val_binary_accuracy: 0.9184
#
# Epoch 00002: loss improved from -0.26404 to -0.46658, saving model to unet_gallbladder_seg.hdf5
# Epoch 3/50
# 826/826 [==============================] - 326s 395ms/step - loss: -0.5414 - dice_coef: 0.5414 - binary_accuracy: 0.9890 - val_loss: -0.2300 - val_dice_coef: 0.3207 - val_binary_accuracy: 0.9315
#
# Epoch 00003: loss improved from -0.46658 to -0.54137, saving model to unet_gallbladder_seg.hdf5
# Epoch 4/50
# 826/826 [==============================] - 328s 397ms/step - loss: -0.5850 - dice_coef: 0.5850 - binary_accuracy: 0.9901 - val_loss: -0.5756 - val_dice_coef: 0.4808 - val_binary_accuracy: 0.9672
#
# Epoch 00004: loss improved from -0.54137 to -0.58497, saving model to unet_gallbladder_seg.hdf5
# Epoch 5/50
# 826/826 [==============================] - 328s 397ms/step - loss: -0.6281 - dice_coef: 0.6281 - binary_accuracy: 0.9917 - val_loss: -0.6632 - val_dice_coef: 0.5451 - val_binary_accuracy: 0.9746
#
# Epoch 00005: loss improved from -0.58497 to -0.62813, saving model to unet_gallbladder_seg.hdf5
# Epoch 6/50
# 826/826 [==============================] - 327s 396ms/step - loss: -0.6686 - dice_coef: 0.6686 - binary_accuracy: 0.9924 - val_loss: -0.3566 - val_dice_coef: 0.5545 - val_binary_accuracy: 0.9751
#
# Epoch 00006: loss improved from -0.62813 to -0.66862, saving model to unet_gallbladder_seg.hdf5
# Epoch 7/50
# 826/826 [==============================] - 327s 396ms/step - loss: -0.6904 - dice_coef: 0.6904 - binary_accuracy: 0.9930 - val_loss: -0.6775 - val_dice_coef: 0.6385 - val_binary_accuracy: 0.9827
#
# Epoch 00007: loss improved from -0.66862 to -0.69039, saving model to unet_gallbladder_seg.hdf5
# Epoch 8/50
# 826/826 [==============================] - 327s 396ms/step - loss: -0.7264 - dice_coef: 0.7264 - binary_accuracy: 0.9938 - val_loss: -0.7044 - val_dice_coef: 0.6519 - val_binary_accuracy: 0.9840
#
# Epoch 00008: loss improved from -0.69039 to -0.72636, saving model to unet_gallbladder_seg.hdf5
# Epoch 9/50
# 826/826 [==============================] - 327s 396ms/step - loss: -0.7401 - dice_coef: 0.7401 - binary_accuracy: 0.9941 - val_loss: -0.8550 - val_dice_coef: 0.7856 - val_binary_accuracy: 0.9920
#
# Epoch 00009: loss improved from -0.72636 to -0.74009, saving model to unet_gallbladder_seg.hdf5
# Epoch 10/50
# 826/826 [==============================] - 327s 396ms/step - loss: -0.7544 - dice_coef: 0.7544 - binary_accuracy: 0.9944 - val_loss: -0.7113 - val_dice_coef: 0.8102 - val_binary_accuracy: 0.9941
#
# Epoch 00010: loss improved from -0.74009 to -0.75437, saving model to unet_gallbladder_seg.hdf5
# Epoch 11/50
# 826/826 [==============================] - 327s 396ms/step - loss: -0.7695 - dice_coef: 0.7695 - binary_accuracy: 0.9948 - val_loss: -0.7811 - val_dice_coef: 0.8337 - val_binary_accuracy: 0.9941
#
# Epoch 00011: loss improved from -0.75437 to -0.76953, saving model to unet_gallbladder_seg.hdf5
# Epoch 12/50
# 826/826 [==============================] - 327s 396ms/step - loss: -0.7736 - dice_coef: 0.7736 - binary_accuracy: 0.9945 - val_loss: -0.8655 - val_dice_coef: 0.8217 - val_binary_accuracy: 0.9936
#
# Epoch 00012: loss improved from -0.76953 to -0.77358, saving model to unet_gallbladder_seg.hdf5
# Epoch 13/50
# 826/826 [==============================] - 327s 396ms/step - loss: -0.7892 - dice_coef: 0.7892 - binary_accuracy: 0.9952 - val_loss: -0.8252 - val_dice_coef: 0.8152 - val_binary_accuracy: 0.9932
#
# Epoch 00013: loss improved from -0.77358 to -0.78919, saving model to unet_gallbladder_seg.hdf5
# Epoch 14/50
# 826/826 [==============================] - 327s 395ms/step - loss: -0.7964 - dice_coef: 0.7964 - binary_accuracy: 0.9953 - val_loss: -0.8987 - val_dice_coef: 0.8391 - val_binary_accuracy: 0.9948
#
# Epoch 00014: loss improved from -0.78919 to -0.79642, saving model to unet_gallbladder_seg.hdf5
# Epoch 15/50
# 826/826 [==============================] - 326s 395ms/step - loss: -0.8065 - dice_coef: 0.8065 - binary_accuracy: 0.9956 - val_loss: -0.8505 - val_dice_coef: 0.8542 - val_binary_accuracy: 0.9951
#
# Epoch 00015: loss improved from -0.79642 to -0.80649, saving model to unet_gallbladder_seg.hdf5
# Epoch 16/50
# 826/826 [==============================] - 326s 395ms/step - loss: -0.8117 - dice_coef: 0.8117 - binary_accuracy: 0.9956 - val_loss: -0.7144 - val_dice_coef: 0.8265 - val_binary_accuracy: 0.9941
#
# Epoch 00016: loss improved from -0.80649 to -0.81168, saving model to unet_gallbladder_seg.hdf5
# Epoch 17/50
# 826/826 [==============================] - 326s 395ms/step - loss: -0.8206 - dice_coef: 0.8206 - binary_accuracy: 0.9959 - val_loss: -0.9119 - val_dice_coef: 0.8038 - val_binary_accuracy: 0.9928
#
# Epoch 00017: loss improved from -0.81168 to -0.82061, saving model to unet_gallbladder_seg.hdf5
# Epoch 18/50
# 826/826 [==============================] - 326s 395ms/step - loss: -0.8286 - dice_coef: 0.8286 - binary_accuracy: 0.9961 - val_loss: -0.9183 - val_dice_coef: 0.8520 - val_binary_accuracy: 0.9951
#
# Epoch 00018: loss improved from -0.82061 to -0.82860, saving model to unet_gallbladder_seg.hdf5
# Epoch 19/50
# 826/826 [==============================] - 326s 395ms/step - loss: -0.8298 - dice_coef: 0.8298 - binary_accuracy: 0.9961 - val_loss: -0.8732 - val_dice_coef: 0.8493 - val_binary_accuracy: 0.9951
#
# Epoch 00019: loss improved from -0.82860 to -0.82979, saving model to unet_gallbladder_seg.hdf5
# Epoch 20/50
# 826/826 [==============================] - 326s 395ms/step - loss: -0.8338 - dice_coef: 0.8338 - binary_accuracy: 0.9961 - val_loss: -0.8684 - val_dice_coef: 0.8304 - val_binary_accuracy: 0.9943
#
# Epoch 00020: loss improved from -0.82979 to -0.83381, saving model to unet_gallbladder_seg.hdf5
# Epoch 21/50
# 826/826 [==============================] - 326s 395ms/step - loss: -0.8423 - dice_coef: 0.8423 - binary_accuracy: 0.9963 - val_loss: -0.8603 - val_dice_coef: 0.8449 - val_binary_accuracy: 0.9949
#
# Epoch 00021: loss improved from -0.83381 to -0.84230, saving model to unet_gallbladder_seg.hdf5
# Epoch 22/50
# 826/826 [==============================] - 326s 395ms/step - loss: -0.8458 - dice_coef: 0.8458 - binary_accuracy: 0.9963 - val_loss: -0.9017 - val_dice_coef: 0.8334 - val_binary_accuracy: 0.9948
#
# Epoch 00022: loss improved from -0.84230 to -0.84582, saving model to unet_gallbladder_seg.hdf5
# Epoch 23/50
# 826/826 [==============================] - 326s 394ms/step - loss: -0.8516 - dice_coef: 0.8516 - binary_accuracy: 0.9965 - val_loss: -0.8561 - val_dice_coef: 0.8403 - val_binary_accuracy: 0.9948
#
# Epoch 00023: loss improved from -0.84582 to -0.85163, saving model to unet_gallbladder_seg.hdf5
# Epoch 24/50
# 826/826 [==============================] - 326s 394ms/step - loss: -0.8520 - dice_coef: 0.8520 - binary_accuracy: 0.9965 - val_loss: -0.7750 - val_dice_coef: 0.8256 - val_binary_accuracy: 0.9939
#
# Epoch 00024: loss improved from -0.85163 to -0.85203, saving model to unet_gallbladder_seg.hdf5
# Epoch 25/50
# 826/826 [==============================] - 325s 394ms/step - loss: -0.8598 - dice_coef: 0.8598 - binary_accuracy: 0.9967 - val_loss: -0.4715 - val_dice_coef: 0.8166 - val_binary_accuracy: 0.9946
#
# Epoch 00025: loss improved from -0.85203 to -0.85981, saving model to unet_gallbladder_seg.hdf5
# Epoch 26/50
# 826/826 [==============================] - 325s 394ms/step - loss: -0.8631 - dice_coef: 0.8631 - binary_accuracy: 0.9968 - val_loss: -0.8741 - val_dice_coef: 0.8385 - val_binary_accuracy: 0.9949
#
# Epoch 00026: loss improved from -0.85981 to -0.86309, saving model to unet_gallbladder_seg.hdf5
# Epoch 27/50
# 826/826 [==============================] - 325s 394ms/step - loss: -0.8651 - dice_coef: 0.8651 - binary_accuracy: 0.9969 - val_loss: -0.8704 - val_dice_coef: 0.8333 - val_binary_accuracy: 0.9945
# Epoch 00027: loss improved from -0.86309 to -0.86509, saving model to unet_gallbladder_seg.hdf5
# Epoch 28/50
# 826/826 [==============================] - 325s 394ms/step - loss: -0.8675 - dice_coef: 0.8675 - binary_accuracy: 0.9969 - val_loss: -0.9070 - val_dice_coef: 0.8468 - val_binary_accuracy: 0.9950
#
# Epoch 00028: loss improved from -0.86509 to -0.86747, saving model to unet_gallbladder_seg.hdf5
# Epoch 29/50
# 826/826 [==============================] - 325s 394ms/step - loss: -0.8704 - dice_coef: 0.8704 - binary_accuracy: 0.9969 - val_loss: -0.8527 - val_dice_coef: 0.8545 - val_binary_accuracy: 0.9953
#
# Epoch 00029: loss improved from -0.86747 to -0.87043, saving model to unet_gallbladder_seg.hdf5
# Epoch 30/50
# 826/826 [==============================] - 325s 394ms/step - loss: -0.8735 - dice_coef: 0.8735 - binary_accuracy: 0.9970 - val_loss: -0.8229 - val_dice_coef: 0.8128 - val_binary_accuracy: 0.9936
#
# Epoch 00030: loss improved from -0.87043 to -0.87355, saving model to unet_gallbladder_seg.hdf5
# Epoch 31/50
# 826/826 [==============================] - 325s 393ms/step - loss: -0.8741 - dice_coef: 0.8741 - binary_accuracy: 0.9970 - val_loss: -0.8854 - val_dice_coef: 0.8440 - val_binary_accuracy: 0.9949
#
# Epoch 00031: loss improved from -0.87355 to -0.87411, saving model to unet_gallbladder_seg.hdf5
# Epoch 32/50
# 826/826 [==============================] - 325s 393ms/step - loss: -0.8801 - dice_coef: 0.8801 - binary_accuracy: 0.9972 - val_loss: -0.8795 - val_dice_coef: 0.7798 - val_binary_accuracy: 0.9919
#
# Epoch 00032: loss improved from -0.87411 to -0.88013, saving model to unet_gallbladder_seg.hdf5
# Epoch 33/50
# 826/826 [==============================] - 325s 393ms/step - loss: -0.8780 - dice_coef: 0.8780 - binary_accuracy: 0.9971 - val_loss: -0.6753 - val_dice_coef: 0.8410 - val_binary_accuracy: 0.9947
#
# Epoch 00033: loss did not improve from -0.88013
# Epoch 34/50
# 826/826 [==============================] - 325s 393ms/step - loss: -0.8767 - dice_coef: 0.8767 - binary_accuracy: 0.9971 - val_loss: -0.9096 - val_dice_coef: 0.8509 - val_binary_accuracy: 0.9952
#
# Epoch 00034: loss did not improve from -0.88013
# Epoch 35/50
# 826/826 [==============================] - 325s 393ms/step - loss: -0.8835 - dice_coef: 0.8835 - binary_accuracy: 0.9973 - val_loss: -0.9141 - val_dice_coef: 0.8507 - val_binary_accuracy: 0.9953
#
# Epoch 00035: loss improved from -0.88013 to -0.88350, saving model to unet_gallbladder_seg.hdf5
# Epoch 36/50
# 826/826 [==============================] - 325s 393ms/step - loss: -0.8884 - dice_coef: 0.8884 - binary_accuracy: 0.9973 - val_loss: -0.8678 - val_dice_coef: 0.8465 - val_binary_accuracy: 0.9950
#
# Epoch 00036: loss improved from -0.88350 to -0.88843, saving model to unet_gallbladder_seg.hdf5
# Epoch 37/50
# 826/826 [==============================] - 325s 393ms/step - loss: -0.8869 - dice_coef: 0.8869 - binary_accuracy: 0.9973 - val_loss: -0.8633 - val_dice_coef: 0.8517 - val_binary_accuracy: 0.9952
#
# Epoch 00037: loss did not improve from -0.88843
# Epoch 38/50
# 826/826 [==============================] - 324s 393ms/step - loss: -0.8897 - dice_coef: 0.8897 - binary_accuracy: 0.9973 - val_loss: -0.8636 - val_dice_coef: 0.8011 - val_binary_accuracy: 0.9932
#
# Epoch 00038: loss improved from -0.88843 to -0.88972, saving model to unet_gallbladder_seg.hdf5
# Epoch 39/50
# 826/826 [==============================] - 324s 393ms/step - loss: -0.8894 - dice_coef: 0.8894 - binary_accuracy: 0.9974 - val_loss: -0.7552 - val_dice_coef: 0.8204 - val_binary_accuracy: 0.9940
#
# Epoch 00039: loss did not improve from -0.88972
# Epoch 40/50
# 826/826 [==============================] - 324s 393ms/step - loss: -0.8924 - dice_coef: 0.8924 - binary_accuracy: 0.9974 - val_loss: -0.9222 - val_dice_coef: 0.8340 - val_binary_accuracy: 0.9947
#
# Epoch 00040: loss improved from -0.88972 to -0.89239, saving model to unet_gallbladder_seg.hdf5
# Epoch 41/50
# 826/826 [==============================] - 324s 392ms/step - loss: -0.8940 - dice_coef: 0.8940 - binary_accuracy: 0.9975 - val_loss: -0.8997 - val_dice_coef: 0.8340 - val_binary_accuracy: 0.9946
#
# Epoch 00041: loss improved from -0.89239 to -0.89403, saving model to unet_gallbladder_seg.hdf5
# Epoch 42/50
# 826/826 [==============================] - 324s 393ms/step - loss: -0.8947 - dice_coef: 0.8947 - binary_accuracy: 0.9975 - val_loss: -0.6841 - val_dice_coef: 0.8408 - val_binary_accuracy: 0.9948
#
# Epoch 00042: loss improved from -0.89403 to -0.89470, saving model to unet_gallbladder_seg.hdf5
# Epoch 43/50
# 826/826 [==============================] - 324s 392ms/step - loss: -0.8950 - dice_coef: 0.8950 - binary_accuracy: 0.9975 - val_loss: -0.8065 - val_dice_coef: 0.8464 - val_binary_accuracy: 0.9948
#
# Epoch 00043: loss improved from -0.89470 to -0.89500, saving model to unet_gallbladder_seg.hdf5
# Epoch 44/50
# 826/826 [==============================] - 324s 392ms/step - loss: -0.8975 - dice_coef: 0.8975 - binary_accuracy: 0.9976 - val_loss: -0.9168 - val_dice_coef: 0.8439 - val_binary_accuracy: 0.9949
#
# Epoch 00044: loss improved from -0.89500 to -0.89755, saving model to unet_gallbladder_seg.hdf5
# Epoch 45/50
# 826/826 [==============================] - 324s 392ms/step - loss: -0.8973 - dice_coef: 0.8973 - binary_accuracy: 0.9975 - val_loss: -0.8938 - val_dice_coef: 0.8499 - val_binary_accuracy: 0.9950
#
# Epoch 00045: loss did not improve from -0.89755
# Epoch 46/50
# 826/826 [==============================] - 324s 392ms/step - loss: -0.9010 - dice_coef: 0.9010 - binary_accuracy: 0.9977 - val_loss: -0.8726 - val_dice_coef: 0.8509 - val_binary_accuracy: 0.9952
#
# Epoch 00046: loss improved from -0.89755 to -0.90098, saving model to unet_gallbladder_seg.hdf5
# Epoch 47/50
# 826/826 [==============================] - 324s 392ms/step - loss: -0.8981 - dice_coef: 0.8981 - binary_accuracy: 0.9976 - val_loss: -0.9152 - val_dice_coef: 0.8466 - val_binary_accuracy: 0.9950
#
# Epoch 00047: loss did not improve from -0.90098
# Epoch 48/50
# 826/826 [==============================] - 324s 392ms/step - loss: -0.9019 - dice_coef: 0.9019 - binary_accuracy: 0.9976 - val_loss: -0.7737 - val_dice_coef: 0.8537 - val_binary_accuracy: 0.9953
#
# Epoch 00048: loss improved from -0.90098 to -0.90189, saving model to unet_gallbladder_seg.hdf5
# Epoch 49/50
# 826/826 [==============================] - 324s 392ms/step - loss: -0.9025 - dice_coef: 0.9025 - binary_accuracy: 0.9977 - val_loss: -0.9075 - val_dice_coef: 0.8364 - val_binary_accuracy: 0.9947
#
# Epoch 00049: loss improved from -0.90189 to -0.90249, saving model to unet_gallbladder_seg.hdf5
# Epoch 50/50
# 826/826 [==============================] - 324s 392ms/step - loss: -0.9049 - dice_coef: 0.9049 - binary_accuracy: 0.9977 - val_loss: -0.8685 - val_dice_coef: 0.8453 - val_binary_accuracy: 0.9950
#
# Epoch 00050: loss improved from -0.90249 to -0.90492, saving model to unet_gallbladder_seg.hdf5

# %% [markdown]
# ## Loss history

# %%
fig, axs = plt.subplots(1, 3, figsize = (15, 4))

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

training_accuracy = history.history['binary_accuracy']
validation_accuracy = history.history['val_binary_accuracy']
training_dice = history.history['dice_coef']
validation_dice = history.history['val_dice_coef']
epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_loss, 'r--')
axs[0].plot(epoch_count, validation_loss, 'b-')
axs[0].legend(['Training Loss', 'Validation Loss'])

axs[1].plot(epoch_count, training_accuracy, 'r--')
axs[1].plot(epoch_count, validation_accuracy, 'b-')
axs[1].legend(['Training Accuracy', 'Validation Accuracy'])

axs[2].plot(epoch_count, training_dice, 'r--')
axs[2].plot(epoch_count, validation_dice, 'b-')
axs[2].legend(['Training Dice_coefficient', 'Validation Dice_coefficient'])

# %% [markdown]
# ## Model Test

# %%
test_folder="test/All"
folder=os.listdir(test_folder)
for case in folder:
    test_file_folder=os.path.join(test_folder,case)
    test_file_folder1=os.path.join(test_file_folder,"CY_AP_512x512")
    test_files=os.listdir(test_file_folder1)
    os.mkdir(os.path.join(test_file_folder,"results"))
    test_gen = test_generator(test_files, test_file_folder1,target_size=(512,512))
    results = model.predict_generator(test_gen, len(test_files), verbose=1)
    save_result(os.path.join(test_file_folder,"results"), results, test_files)
# Out:
# 107/107 [==============================] - 9s 82ms/step
# 114/114 [==============================] - 6s 49ms/step
# 108/108 [==============================] - 5s 49ms/step
# 124/124 [==============================] - 6s 50ms/step
# 98/98 [==============================] - 5s 50ms/step
# 114/114 [==============================] - 6s 50ms/step
# 100/100 [==============================] - 5s 50ms/step
# 90/90 [==============================] - 5s 51ms/step
# 109/109 [==============================] - 6s 51ms/step
# 109/109 [==============================] - 6s 51ms/step
# 108/108 [==============================] - 6s 51ms/step
# 101/101 [==============================] - 5s 52ms/step
# 107/107 [==============================] - 5s 51ms/step
# 95/95 [==============================] - 5s 51ms/step
# 96/96 [==============================] - 5s 52ms/step
# 111/111 [==============================] - 6s 52ms/step
# 110/110 [==============================] - 6s 51ms/step
# 105/105 [==============================] - 5s 52ms/step
# 118/118 [==============================] - 6s 52ms/step
# 100/100 [==============================] - 5s 52ms/step
# 91/91 [==============================] - 5s 52ms/step
# 104/104 [==============================] - 5s 52ms/step
# 106/106 [==============================] - 5s 52ms/step
# 103/103 [==============================] - 5s 52ms/step
# 117/117 [==============================] - 6s 52ms/step
# 112/112 [==============================] - 6s 53ms/step
# 99/99 [==============================] - 5s 52ms/step
# 83/83 [==============================] - 4s 52ms/step
# 96/96 [==============================] - 5s 53ms/step
# 115/115 [==============================] - 6s 52ms/step
# 113/113 [==============================] - 6s 53ms/step
# 91/91 [==============================] - 5s 53ms/step
# 89/89 [==============================] - 5s 52ms/step
# 84/84 [==============================] - 4s 52ms/step
# 129/129 [==============================] - 7s 52ms/step
# 108/108 [==============================] - 6s 52ms/step
# 94/94 [==============================] - 5s 52ms/step
# 93/93 [==============================] - 5s 52ms/step
# 111/111 [==============================] - 6s 52ms/step
# 108/108 [==============================] - 6s 53ms/step
# 87/87 [==============================] - 5s 52ms/step
# 101/101 [==============================] - 5s 52ms/step
# 87/87 [==============================] - 5s 52ms/step

# %%
image = cv2.imread("case/image/28.jpg")
predict_image = cv2.imread("case/result/28_predict.jpg")
mask_image = cv2.imread("case/mask/28.jpg")

fig, axs = plt.subplots(2, 3, figsize=(16, 16))
list0=[]
axs[0, 0].set_title("Predicted")
axs[0, 0].axes.get_xaxis().set_visible(False)
axs[0, 0].axes.get_yaxis().set_visible(False)
axs[0, 0].imshow(add_colored_mask(image, predict_image))
axs[0, 1].set_title("mask")
axs[0, 1].axes.get_xaxis().set_visible(False)
axs[0, 1].axes.get_yaxis().set_visible(False)
axs[0, 1].imshow(add_colored_mask(image, mask_image))
axs[0, 2].set_title("Diff.")
axs[0, 2].axes.get_xaxis().set_visible(False)
axs[0, 2].axes.get_yaxis().set_visible(False)
axs[0, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("case/image/31.jpg")
predict_image = cv2.imread("case/result/31_predict.jpg")
mask_image = cv2.imread("case/mask/31.jpg")

axs[1, 0].set_title("Predicted")
axs[1, 0].axes.get_xaxis().set_visible(False)
axs[1, 0].axes.get_yaxis().set_visible(False)
axs[1, 0].imshow(add_colored_mask(image, predict_image))
axs[1, 1].set_title("mask")
axs[1, 1].axes.get_xaxis().set_visible(False)
axs[1, 1].axes.get_yaxis().set_visible(False)
axs[1, 1].imshow(add_colored_mask(image, mask_image))

axs[1, 2].set_title("Diff.")
axs[1, 2].axes.get_xaxis().set_visible(False)
axs[1, 2].axes.get_yaxis().set_visible(False)
axs[1, 2].imshow(diff_mask(mask_image, predict_image))

# %%
model = load_model('unet_gallbladder_seg.hdf5', compile=False)

# %%
test_data_folder="test/image/"
test_files=[file for file in os.listdir(test_data_folder) if file.lower().endswith('.jpg')]
test_gen = test_generator(test_files,test_data_folder ,target_size=(512,512))
results = model.predict_generator(test_gen, len(test_files), verbose=1)
save_result("test/result/", results, test_files)
# Out:
# 40/40 [==============================] - 9s 232ms/step
